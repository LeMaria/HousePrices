# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Visualizing Data
# ## Loading the dataset

# %%
#load dataset
import src.utils.data_processing as dp
train, test = dp.loadData()
train = train.set_index('Id')
test = test.set_index('Id')

# %% [markdown]
# ## Data exploration
# ### Summary Statistics
# #### Summary for numerical features

# %%
nfsummary_train = dp.getSummaryForNumericalFeatures(train)
nfsummary_test = dp.getSummaryForNumericalFeatures(test)

# %%
nfsummary_train
# Out:
#                 count           mean           std      min        25%  \
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# ...

# %%
nfsummary_test
# Out:
#                 count         mean          std     min      25%     50%  \
# MSSubClass     1459.0    57.378341    42.746880    20.0    20.00    50.0
# LotFrontage    1232.0    68.580357    22.376841    21.0    58.00    67.0
# LotArea        1459.0  9819.161069  4955.517327  1470.0  7391.00  9399.0
# OverallQual    1459.0     6.078821     1.436812     1.0     5.00     6.0
# OverallCond    1459.0     5.553804     1.113740     1.0     5.00     5.0
# YearBuilt      1459.0  1971.357779    30.390071  1879.0  1953.00  1973.0
# YearRemodAdd   1459.0  1983.662783    21.130467  1950.0  1963.00  1992.0
# MasVnrArea     1444.0   100.709141   177.625900     0.0     0.00     0.0
# BsmtFinSF1     1458.0   439.203704   455.268042     0.0     0.00   350.5
# BsmtFinSF2     1458.0    52.619342   176.753926     0.0     0.00     0.0
# BsmtUnfSF      1458.0   554.294925   437.260486     0.0   219.25   460.0
# TotalBsmtSF    1458.0  1046.117970   442.898624     0.0   784.00   988.0
# ...

# %% [markdown]
# #### Summary for numerical features

# %%
cfsummary_train = dp.getSummaryForCategoricalFeatures(train)
cfsummary_test = dp.getSummaryForCategoricalFeatures(test)

# %%
cfsummary_train
# Out:
#               count unique      top  freq
# MSZoning       1460      5       RL  1151
# Street         1460      2     Pave  1454
# Alley            91      2     Grvl    50
# LotShape       1460      4      Reg   925
# LandContour    1460      4      Lvl  1311
# Utilities      1460      2   AllPub  1459
# LotConfig      1460      5   Inside  1052
# LandSlope      1460      3      Gtl  1382
# Neighborhood   1460     25    NAmes   225
# Condition1     1460      9     Norm  1260
# Condition2     1460      8     Norm  1445
# BldgType       1460      5     1Fam  1220
# HouseStyle     1460      8   1Story   726
# RoofStyle      1460      6    Gable  1141
# RoofMatl       1460      8  CompShg  1434
# Exterior1st    1460     15  VinylSd   515
# Exterior2nd    1460     16  VinylSd   504
# MasVnrType      588      3  BrkFace   445
# ExterQual      1460      4       TA   906
# ExterCond      1460      5       TA  1282
# Foundation     1460      6    PConc   647
# ...

# %%
cfsummary_test
# Out:
#               count unique      top  freq
# MSZoning       1455      5       RL  1114
# Street         1459      2     Pave  1453
# Alley           107      2     Grvl    70
# LotShape       1459      4      Reg   934
# LandContour    1459      4      Lvl  1311
# Utilities      1457      1   AllPub  1457
# LotConfig      1459      5   Inside  1081
# LandSlope      1459      3      Gtl  1396
# Neighborhood   1459     25    NAmes   218
# Condition1     1459      9     Norm  1251
# Condition2     1459      5     Norm  1444
# BldgType       1459      5     1Fam  1205
# HouseStyle     1459      7   1Story   745
# RoofStyle      1459      6    Gable  1169
# RoofMatl       1459      4  CompShg  1442
# Exterior1st    1458     13  VinylSd   510
# Exterior2nd    1458     15  VinylSd   510
# MasVnrType      565      3  BrkFace   434
# ExterQual      1459      4       TA   892
# ExterCond      1459      5       TA  1256
# Foundation     1459      6    PConc   661
# ...

# %%
mvsummary_train = dp.getSummaryForMissingValues(train)
mvsummary_test = dp.getSummaryForMissingValues(test)

# %%
mvsummary_train
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
mvsummary_test
# Out:
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType       894
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64

# %% [markdown]
# #### Observation from the Summaries
# The count does not match up with the maximum number of entries for a lot of features. There are missing values.
# ### Examining

# %%
train.describe()['SalePrice']
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
dp.plotHistogram(train, 'SalePrice')

# %%
df_num = train.select_dtypes(include = ['float64', 'int64'])

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<Axes: title={'center': 'MSSubClass'}>,
#         <Axes: title={'center': 'LotFrontage'}>,
#         <Axes: title={'center': 'LotArea'}>,
#         <Axes: title={'center': 'OverallQual'}>,
#         <Axes: title={'center': 'OverallCond'}>,
#         <Axes: title={'center': 'YearBuilt'}>],
#        [<Axes: title={'center': 'YearRemodAdd'}>,
#         <Axes: title={'center': 'MasVnrArea'}>,
#         <Axes: title={'center': 'BsmtFinSF1'}>,
#         <Axes: title={'center': 'BsmtFinSF2'}>,
#         <Axes: title={'center': 'BsmtUnfSF'}>,
#         <Axes: title={'center': 'TotalBsmtSF'}>],
#        [<Axes: title={'center': '1stFlrSF'}>,
#         <Axes: title={'center': '2ndFlrSF'}>,
#         <Axes: title={'center': 'LowQualFinSF'}>,
#         <Axes: title={'center': 'GrLivArea'}>,
#         <Axes: title={'center': 'BsmtFullBath'}>,
#         <Axes: title={'center': 'BsmtHalfBath'}>],
#        [<Axes: title={'center': 'FullBath'}>,
# ...

# %% [markdown]
# ### Exploring Feature with Target relationships
# #### Mutual Information between features and target

# %%
X = train.copy()
dp.encodeDataForMI(X)
Y = X.pop('SalePrice')

mi_score = dp.getMIScore(X, Y)
dp.plotMIScore(mi_score)

# %% [markdown]
# #### Scatterplots between Numerical Features and Target

# %%
dp.plotScatterForFeatures(train, 'GrLivArea', 'SalePrice')

# %%
dp.plotScatterForFeatures(train, 'TotalBsmtSF', 'SalePrice')

# %%
dp.plotScatterForFeatures(train, 'YearBuilt', 'SalePrice')

# %%
dp.plotScatterForFeatures(train, 'GarageArea', 'SalePrice')

# %%
dp.plotScatterForFeatures(train, '1stFlrSF', 'SalePrice')

# %% [markdown]
# #### Boxplots between Categorical Features and Target

# %%
dp.plotBoxPlotForFeatures(train, 'OverallQual', 'SalePrice')

# %%
dp.plotBoxPlotForFeatures(train, 'YearBuilt', 'SalePrice')

# %%
dp.plotBoxPlotForFeatures(train, 'GarageCars', 'SalePrice')

# %%
dp.plotBoxPlotForFeatures(train, 'ExterQual', 'SalePrice')

# %% [markdown]
# ### Exploring inter Feature relationships
# #### Correlation Heatmap of top 10 Features

# %%
dp.plotCorrelationMatrix(train, 'SalePrice')

# %% [markdown]
# ### Observations
#
# * Missing data in certain columns -> Delete columns with missing values
# * features 'OverallQual' and 'GrLivArea' are strongly correlated with SalePrice
# * strong inter feature correlation: -> remove one to remove redudancy
#     * 'GarageArea' and 'GarageCars' are strongly correlated with each other -> remove 'GarageArea'
#     * 'TotRmsAbvGrd' and 'GrLivArea' are strongly correlated with each other -> remove 'TotRmsAbvGrd'
#     * 'TotalBsmtSF' and '1stFlrSF' are strongly correlated with each other -> remove '1stFlrSF'

# %%
missing_values = (train.isnull().sum())
missing_values
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64
